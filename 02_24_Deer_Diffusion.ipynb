# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib notebook 

n_animals = 100
n_steps = 100
diffusion_speed = 0.01

x = np.ones(n_animals)*0.5 
y = np.ones(n_animals)*0.5

fig = plt.figure(figsize=(5,5));
plt.show()

for t in range(n_steps):
    x+= np.random.randn(n_animals)*diffusion_speed
    y+= np.random.randn(n_animals)*diffusion_speed
    
    plt.cla()
    plt.plot(x,y,'k.',markersize=2);
    plt.xlim((0,1));
    plt.ylim((0,1));
    fig.canvas.draw() 
    time.sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="498.88890210493145">

# %%
# %matplotlib notebook 

n_animals = 100
n_steps = 100
diffusion_speed = 0.05

x = np.ones(n_animals)*0.5 
y = np.ones(n_animals)*0.5

fig = plt.figure(figsize=(5,5));
plt.show()

for t in range(n_steps):
    x+= np.random.randn(n_animals)*diffusion_speed
    y+= np.random.randn(n_animals)*diffusion_speed
    for i in range(n_steps):
        if x[i] >= 1:
            x[i] = 1
        elif x[i] <= 0:
            x[i] = 0
        if y[i] >= 1:
            y[i] = 1
        elif y[i] <= 0:
            y[i] = 0
        else:
            pass
    plt.cla()
    plt.plot(x,y,'k.',markersize=2);
    plt.xlim((0,1));
    plt.ylim((0,1));
    fig.canvas.draw() 
    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="498.88890210493145">

# %%
# %matplotlib notebook 

n_animals = 100
n_steps = 100
diffusion_speed = 0.05

x = np.ones(n_animals)*0.5 
y = np.ones(n_animals)*0.5

fig = plt.figure(figsize=(5,5));
plt.show()

for t in range(n_steps):
    x+= np.random.randn(n_animals)*diffusion_speed
    y+= np.random.randn(n_animals)*diffusion_speed
    for i in range(n_animals):
        if x[i] < 0: x[i] = 0
        if x[i] > 1: x[i] = 1
        if y[i] < 0: x[i] = 0
        if y[i] > 1: y[i] = 1
        
    plt.clf()
    plt.plot(x,y,'k.',markersize=2);
    plt.xlim((0,1));
    plt.ylim((0,1));
    fig.canvas.draw() 
    time.sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %%
# Option #1: Loop (slow)
a = np.array([1,2,3,-7,4]) 
for i in range(len(a)):
    if a[i] < 0: a[i] = 0
print(a)

# Option #2: Boolean indexing (fast)
a = np.array([1,2,3,-7,4]) 
print('a<0:',a<0)
print('a[a<0]:',a[a<0]) # logical indexing
a[a<0] = 0 # only sets values for those elements where the condition is true
print(a)

# Option #2.5: Boolean conditioning with np.where
a = np.array([1,2,3,-7,4]) 
a = np.where(a>0,a,0)
print(a)

# Option #3: Vectorized formula (fast), Arseny-approved
a = np.array([1,2,3,-7,4]) 
a = np.maximum(a,0)
print(a)
# Out:
# [1 2 3 0 4]
# a<0: [False False False  True False]
# a[a<0]: [-7]
# [1 2 3 0 4]
# [1 2 3 0 4]
# [1 2 3 0 4]

# %%
# %matplotlib notebook 

n_animals = 100
n_steps = 100
diffusion_speed = 0.05

x = np.ones(n_animals)*0.5 
y = np.ones(n_animals)*0.5

fig = plt.figure(figsize=(5,5));
plt.show()

for t in range(n_steps):
    x+= np.random.randn(n_animals)*diffusion_speed
    y+= np.random.randn(n_animals)*diffusion_speed
    x[t] = np.maximum(x[t],0)
    y[t] = np.maximum(y[t],0)
    
    plt.clf()
    plt.plot(x,y,'k.',markersize=2);
    plt.xlim((0,1));
    plt.ylim((0,1));
    fig.canvas.draw() 
    time.sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="498.88890210493145">
